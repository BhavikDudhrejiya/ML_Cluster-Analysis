# %%
#Importing libraries
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn import datasets
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Loading data
data = pd.read_csv('C:/Users/bhavi/OneDrive/Desktop/Data/KMeans.csv')

# %%
#View the data
data.head()
# Out:
#    Age  Annual Income (k$)  Spending Score (1-100)
# 0   19                  15                      39
# 1   21                  15                      81
# 2   20                  16                       6
# 3   23                  16                      77
# 4   31                  17                      40

# %%
#Creating X data with a variables annual income and spending score
X = data.iloc[:,[1,2]].values
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
#Implementing standard scaler on X dataset
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[-1.73899919, -0.43480148],
#        [-1.73899919,  1.19570407],
#        [-1.70082976, -1.71591298],
#        [-1.70082976,  1.04041783],
#        [-1.66266033, -0.39597992],
#        [-1.66266033,  1.00159627],
#        [-1.62449091, -1.71591298],
#        [-1.62449091,  1.70038436],
#        [-1.58632148, -1.83237767],
#        [-1.58632148,  0.84631002],
#        [-1.58632148, -1.4053405 ],
#        [-1.58632148,  1.89449216],
#        [-1.54815205, -1.36651894],
#        [-1.54815205,  1.04041783],
#        [-1.54815205, -1.44416206],
#        [-1.54815205,  1.11806095],
#        [-1.50998262, -0.59008772],
#        [-1.50998262,  0.61338066],
#        [-1.43364376, -0.82301709],
#        [-1.43364376,  1.8556706 ],
#        [-1.39547433, -0.59008772],
#        [-1.39547433,  0.88513158],
#        [-1.3573049 , -1.75473454],
#        [-1.3573049 ,  0.88513158],
#        [-1.24279661, -1.4053405 ],
#        [-1.24279661,  1.23452563],
#        [-1.24279661, -0.7065524 ],
# ...

# %%
ns = 3
nbrs = NearestNeighbors(n_neighbors=ns).fit(X)
nbrs
# Out:
# NearestNeighbors(n_neighbors=3)

# %%
nbrs.kneighbors(X)
# Out:
# (array([[0.        , 0.08564307, 0.27669913],
#         [0.        , 0.15990848, 0.20603662],
#         [0.        , 0.07633886, 0.16332841],
#         [0.        , 0.0544428 , 0.15267772],
#         [0.        , 0.08564307, 0.24695814],
#         [0.        , 0.0544428 , 0.12091014],
#         [0.        , 0.07633886, 0.12255989],
#         [0.        , 0.19782504, 0.24604156],
#         [0.        , 0.12255989, 0.16332841],
#         [0.        , 0.17303595, 0.19475561],
#         [0.        , 0.0544428 , 0.0544428 ],
#         [0.        , 0.15753602, 0.19782504],
#         [0.        , 0.0544428 , 0.07764312],
#         [0.        , 0.07764312, 0.12091014],
#         [0.        , 0.0544428 , 0.07764312],
#         [0.        , 0.07764312, 0.16332841],
#         [0.        , 0.11450829, 0.24511979],
#         [0.        , 0.24511979, 0.29489102],
#         [0.        , 0.22357696, 0.236036  ],
#         [0.        , 0.15753602, 0.24604156],
# ...

# %%
distances
# Out:
# (array([[0.        , 0.08564307, 0.27669913],
#         [0.        , 0.15990848, 0.20603662],
#         [0.        , 0.07633886, 0.16332841],
#         [0.        , 0.0544428 , 0.15267772],
#         [0.        , 0.08564307, 0.24695814],
#         [0.        , 0.0544428 , 0.12091014],
#         [0.        , 0.07633886, 0.12255989],
#         [0.        , 0.19782504, 0.24604156],
#         [0.        , 0.12255989, 0.16332841],
#         [0.        , 0.17303595, 0.19475561],
#         [0.        , 0.0544428 , 0.0544428 ],
#         [0.        , 0.15753602, 0.19782504],
#         [0.        , 0.0544428 , 0.07764312],
#         [0.        , 0.07764312, 0.12091014],
#         [0.        , 0.0544428 , 0.07764312],
#         [0.        , 0.07764312, 0.16332841],
#         [0.        , 0.11450829, 0.24511979],
#         [0.        , 0.24511979, 0.29489102],
#         [0.        , 0.22357696, 0.236036  ],
#         [0.        , 0.15753602, 0.24604156],
# ...

# %%
indices
# Out:
# (array([[0.        , 0.08564307, 0.27669913],
#         [0.        , 0.15990848, 0.20603662],
#         [0.        , 0.07633886, 0.16332841],
#         [0.        , 0.0544428 , 0.15267772],
#         [0.        , 0.08564307, 0.24695814],
#         [0.        , 0.0544428 , 0.12091014],
#         [0.        , 0.07633886, 0.12255989],
#         [0.        , 0.19782504, 0.24604156],
#         [0.        , 0.12255989, 0.16332841],
#         [0.        , 0.17303595, 0.19475561],
#         [0.        , 0.0544428 , 0.0544428 ],
#         [0.        , 0.15753602, 0.19782504],
#         [0.        , 0.0544428 , 0.07764312],
#         [0.        , 0.07764312, 0.12091014],
#         [0.        , 0.0544428 , 0.07764312],
#         [0.        , 0.07764312, 0.16332841],
#         [0.        , 0.11450829, 0.24511979],
#         [0.        , 0.24511979, 0.29489102],
#         [0.        , 0.22357696, 0.236036  ],
#         [0.        , 0.15753602, 0.24604156],
# ...

# %%
distanceDec = sorted(distances[:,ns-1],reverse=True)
distanceDec
# Out:
# [0.6672027095648378,
#  0.6535090609453799,
#  0.587305862316214,
#  0.5725414375765854,
#  0.5718364291710365,
#  0.5462249937357125,
#  0.5370407021791156,
#  0.5370407021791156,
#  0.5191078371534682,
#  0.5174618169414061,
#  0.4977189098412889,
#  0.4658587285383729,
#  0.41986372088949575,
#  0.3945721361033899,
#  0.35538311280453044,
#  0.3514727656386843,
#  0.34607189143564526,
#  0.30781334322477255,
#  0.294891019085977,
#  0.2822697052839207,
#  0.27850776274931804,
#  0.27823877362072436,
#  0.27669913056608536,
#  0.27441842239757613,
#  0.27441842239757613,
#  0.27441842239757613,
#  0.25955391857673393,
#  0.2569292000210834,
#  0.2569292000210834,
#  0.24695814336595695,
#  0.24695814336595695,
#  0.24695814336595676,
#  0.24604156213887768,
#  0.24604156213887768,
#  0.24604156213887768,
#  0.24511978710835072,
#  0.2418202761206728,
#  0.2418202761206728,
#  0.23603600162294383,
#  0.2360360016229438,
#  0.23603600162294375,
#  0.2360360016229437,
# ...

# %%
plt.plot(indices[:,0], distanceDec)

# %%
db = DBSCAN(eps = 0.3, min_samples=10).fit(X)
core_sample_mask = np.zero_like(db.labels_, dtype = bool)
core_sample_mask[db.core_sample_indices_]=True
labels = db.labels_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5419d0e24453> in <module>
# ----> 1 db = DBSCAN(eps = 0.3, min_samples=10).fit(X)
#       2 core_sample_mask = np.zero_like(db.labels_, dtype = bool)
#       3 core_sample_mask[db.core_sample_indices_]=True
#       4 labels = db.labels_
#
# NameError: name 'X' is not defined
